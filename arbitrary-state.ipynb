# %% [markdown]
# ## Hadamard Superposition

# %%
from qiskit import QuantumCircuit, transpile, assemble
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# %%
# Step 1: Create a Quantum Circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)

# Step 2: Apply a Hadamard gate to put the qubit in superposition
qc.h(0)

# Step 3: Measure the qubit and store the result in the classical bit
qc.measure(0, 0)

# %%
qc.draw(output='mpl')

# %%
# Step 4: Execute the circuit on a simulator
simulator = AerSimulator()
result = simulator.run(qc).result()

# %%
# Step 5: Get the measurement results
counts = result.get_counts(qc)
print(counts)

# Visualize the results
plot_histogram(counts)
# Out:
# {'1': 514, '0': 510}

# %% [markdown]
# ## Arbirary Superposition

# %%
# Import Qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_bloch_multivector
from math import pi
import random

# %%
# Step 1: Define parameters
theta = Parameter('θ')
phi = Parameter('φ')

# %%
qc = QuantumCircuit(1, 1)

# Step 2: Apply rotation gates to prepare the arbitrary state
qc.ry(theta, 0)
qc.rz(phi, 0)

# %%
qc.draw(output='mpl')

# %%
# Step 3: Assign specific values to the parameters
param_dict = {theta: random.uniform(-pi, pi), phi: random.uniform(-pi, pi)}
param_dict = {theta: pi/2, phi: pi/2}
qc_bound = qc.assign_parameters(param_dict)
qc_bound.measure(0, 0)

# %%
qc_bound.draw(output='mpl')

# %%
# Step 4: Execute the circuit on a simulator
simulator = AerSimulator()
result = simulator.run(qc_bound).result()

# %%
# Step 5: Get the measurement results
counts = result.get_counts(qc_bound)
print(counts)

# Visualize the results
plot_histogram(counts)
# Out:
# {'1': 509, '0': 515}
