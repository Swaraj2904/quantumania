# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %%
# Create a quantum circuit with two qubits
qc = QuantumCircuit(2)

# Apply a Hadamard gate to the first qubit
qc.h(0)

# Apply a Phase (S) gate to the first qubit
qc.s(0)

# Apply a CNOT gate with the first qubit as control and the second as target
qc.cx(0, 1)

qc.measure_all()

# %%
# Draw the circuit
qc.draw('mpl')

# %%
simulator = AerSimulator()
result = simulator.run(qc).result()

# %%
result
# Out:
# Result(backend_name='aer_simulator', backend_version='0.14.2', qobj_id='', job_id='5e7dd559-4d59-48b3-a77f-36b8fb7af646', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 535, '0x3': 489}), header=QobjExperimentHeader(creg_sizes=[['meas', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-168', qreg_sizes=[['q', 2]], metadata={}), status=DONE, seed_simulator=3532199218, metadata={'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 8, 'parallel_shots': 1, 'sample_measure_time': 0.000760709, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.003326417, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}, time_taken=0.003326417)], date=2024-07-21T15:27:57.048449, status=COMPLETED, header=None, metadata={'time_taken_parameter_binding': 1.7291e-05, 'max_memory_mb': 16384, 'time_taken_execute': 0.003438375, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'parallel_experiments': 1}, time_taken=0.00445103645324707)

# %%
# Step 5: Get the measurement results
counts = result.get_counts(qc)
print(counts)

# Visualize the results
plot_histogram(counts)
# Out:
# {'00': 535, '11': 489}
